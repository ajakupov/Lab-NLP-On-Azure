# %%
# !pip install azure-ai-textanalytics --pre
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Collecting azure-ai-textanalytics
#   Downloading azure_ai_textanalytics-5.1.0b5-py2.py3-none-any.whl (134 kB)
#      |████████████████████████████████| 134 kB 5.2 MB/s
# Collecting azure-common~=1.1
#   Downloading azure_common-1.1.26-py2.py3-none-any.whl (12 kB)
# Collecting msrest&gt;=0.6.0
#   Downloading msrest-0.6.21-py2.py3-none-any.whl (85 kB)
#      |████████████████████████████████| 85 kB 2.6 MB/s
# Requirement already satisfied: six&gt;=1.11.0 in /databricks/python3/lib/python3.7/site-packages (from azure-ai-textanalytics) (1.14.0)
# Collecting azure-core&lt;2.0.0,&gt;=1.8.2
#   Downloading azure_core-1.12.0b1-py2.py3-none-any.whl (128 kB)
#      |████████████████████████████████| 128 kB 7.9 MB/s
# Collecting isodate&gt;=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
#      |████████████████████████████████| 45 kB 3.1 MB/s
# Requirement already satisfied: requests~=2.16 in /databricks/python3/lib/python3.7/site-packages (from msrest&gt;=0.6.0-&gt;azure-ai-textanalytics) (2.22.0)
# Collecting requests-oauthlib&gt;=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: certifi&gt;=2017.4.17 in /databricks/python3/lib/python3.7/site-packages (from msrest&gt;=0.6.0-&gt;azure-ai-textanalytics) (2020.6.20)
# Requirement already satisfied: idna&lt;2.9,&gt;=2.5 in /databricks/python3/lib/python3.7/site-packages (from requests~=2.16-&gt;msrest&gt;=0.6.0-&gt;azure-ai-textanalytics) (2.8)
# Requirement already satisfied: chardet&lt;3.1.0,&gt;=3.0.2 in /usr/lib/python3/dist-packages (from requests~=2.16-&gt;msrest&gt;=0.6.0-&gt;azure-ai-textanalytics) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,&lt;1.26,&gt;=1.21.1 in /databricks/python3/lib/python3.7/site-packages (from requests~=2.16-&gt;msrest&gt;=0.6.0-&gt;azure-ai-textanalytics) (1.25.8)
# Collecting oauthlib&gt;=3.0.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
#      |████████████████████████████████| 147 kB 8.2 MB/s
# Installing collected packages: azure-common, isodate, oauthlib, requests-oauthlib, msrest, azure-core, azure-ai-textanalytics
# Successfully installed azure-ai-textanalytics-5.1.0b5 azure-common-1.1.26 azure-core-1.12.0b1 isodate-0.6.0 msrest-0.6.21 oauthlib-3.1.0 requests-oauthlib-1.3.0
# <span class="ansi-yellow-fg">WARNING: You are using pip version 20.0.2; however, version 21.0.1 is available.
# You should consider upgrading via the &#39;/databricks/python3/bin/python3.7 -m pip install --upgrade pip&#39; command.</span>
# </div>

# %%
import pandas as pd

from collections import Counter

from azure.ai.textanalytics import TextAnalyticsClient
from azure.core.credentials import AzureKeyCredential
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
key = "d24e8cb0841042fea278d63148d1596f"
endpoint = "https://danonetxtanltx.cognitiveservices.azure.com/"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
def authenticate_client():
    ta_credential = AzureKeyCredential(key)
    text_analytics_client = TextAnalyticsClient(
            endpoint=endpoint, 
            credential=ta_credential)
    return text_analytics_client

client = authenticate_client()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
def get_sentiment(client, tweet):
  documents = [tweet]
  response = client.analyze_sentiment(documents=documents)[0]
  return response.sentiment
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
tweets = pd.read_csv("/dbfs/FileStore/shared_uploads/ajakupov@expertime.com/train.csv")

tweets = tweets.dropna(how='any')
tweets['NumWords'] = tweets['tweet'].apply(lambda x: len(str(x).split()))
tweets = tweets[tweets['NumWords']>3]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
tweets_lite = tweets.head(100)
tweets_lite['Sentiment']=tweets_lite['tweet'].apply(lambda x: get_sentiment(client, x))

tweets_lite
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/local_disk0/tmp/1613030460415-0/PythonShell.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # The first line is intentionally left blank because warnings.warn in a notebook will include it.
# Out[58]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>label</th>
#       <th>tweet</th>
#       <th>NumWords</th>
#       <th>Sentiment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>0</td>
#       <td>@user when a father is dysfunctional and is s...</td>
#       <td>18</td>
#       <td>negative</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>0</td>
#       <td>@user @user thanks for #lyft credit i can't us...</td>
#       <td>19</td>
#       <td>mixed</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>0</td>
#       <td>#model   i love u take with u all the time in ...</td>
#       <td>14</td>
#       <td>positive</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>0</td>
#       <td>factsguide: society now    #motivation</td>
#       <td>4</td>
#       <td>positive</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>6</td>
#       <td>0</td>
#       <td>[2/2] huge fan fare and big talking before the...</td>
#       <td>19</td>
#       <td>negative</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>97</th>
#       <td>98</td>
#       <td>0</td>
#       <td>couple having sex fat naked japanese girls</td>
#       <td>7</td>
#       <td>neutral</td>
#     </tr>
#     <tr>
#       <th>98</th>
#       <td>99</td>
#       <td>0</td>
#       <td>#hump on that    #hump day #humpersð© @ edwa...</td>
#       <td>9</td>
#       <td>neutral</td>
#     </tr>
#     <tr>
#       <th>99</th>
#       <td>100</td>
#       <td>0</td>
#       <td>personalised we... gbp 7.99 get here:  #shop #...</td>
#       <td>10</td>
#       <td>positive</td>
#     </tr>
#     <tr>
#       <th>100</th>
#       <td>101</td>
#       <td>0</td>
#       <td>there are some truly sick ppl out there.</td>
#       <td>8</td>
#       <td>negative</td>
#     </tr>
#     <tr>
#       <th>101</th>
#       <td>102</td>
#       <td>0</td>
#       <td>trump calling on obama to resign over the orla...</td>
#       <td>25</td>
#       <td>neutral</td>
#     </tr>
#   </tbody>
# </table>
# <p>100 rows × 5 columns</p>
# </div>

# %%
tweets.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[40]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>label</th>
#       <th>tweet</th>
#       <th>NumWords</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>0</td>
#       <td>@user when a father is dysfunctional and is s...</td>
#       <td>18</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>0</td>
#       <td>@user @user thanks for #lyft credit i can't us...</td>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>0</td>
#       <td>#model   i love u take with u all the time in ...</td>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>0</td>
#       <td>factsguide: society now    #motivation</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>6</td>
#       <td>0</td>
#       <td>[2/2] huge fan fare and big talking before the...</td>
#       <td>19</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
counter = Counter(tweets['label'])
counter
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[41]: Counter({0: 29157, 1: 2222})</div>

# %%
def sentiment_analysis_example(client):

    documents = ["I had the best day of my life. I wish you were there with me."]
    response = client.analyze_sentiment(documents=documents)[0]
    print("Document Sentiment: {}".format(response.sentiment))
    print("Overall scores: positive={0:.2f}; neutral={1:.2f}; negative={2:.2f} \n".format(
        response.confidence_scores.positive,
        response.confidence_scores.neutral,
        response.confidence_scores.negative,
    ))
    for idx, sentence in enumerate(response.sentences):
        print("Sentence: {}".format(sentence.text))
        print("Sentence {} sentiment: {}".format(idx+1, sentence.sentiment))
        print("Sentence score:\nPositive={0:.2f}\nNeutral={1:.2f}\nNegative={2:.2f}\n".format(
            sentence.confidence_scores.positive,
            sentence.confidence_scores.neutral,
            sentence.confidence_scores.negative,
        ))
          
sentiment_analysis_example(client)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Document Sentiment: positive
# Overall scores: positive=1.00; neutral=0.00; negative=0.00
#
# Sentence: I had the best day of my life.
# Sentence 1 sentiment: positive
# Sentence score:
# Positive=1.00
# Neutral=0.00
# Negative=0.00
#
# Sentence: I wish you were there with me.
# Sentence 2 sentiment: neutral
# Sentence score:
# Positive=0.21
# Neutral=0.77
# Negative=0.02
#
# </div>

# %%
CHUNK_SIZE = 10

documents = list(tweets.head(20)['tweet'])

sentiments = []

i = 0
while i < len(documents):
  batch = documents[i:i+CHUNK_SIZE]
  responses = client.analyze_sentiment(documents=batch)
  print (responses)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[AnalyzeSentimentResult(id=0, sentiment=negative, warnings=[], statistics=None, confidence_scores=SentimentConfidenceScores(positive=0.0, neutral=0.0, negative=1.0), sentences=[SentenceSentiment(text= @user when a father is dysfunctional and is so selfish he drags his kids into his dysfunction., sentiment=negative, confidence_scores=SentimentConfidenceScores(positive=0.0, neutral=0.0, negative=1.0), length=95, offset=0, mined_opinions=[]), SentenceSentiment(text=#run, sentiment=neutral, confidence_scores=SentimentConfidenceScores(positive=0.02, neutral=0.94, negative=0.04), length=4, offset=98, mined_opinions=[])], is_error=False), AnalyzeSentimentResult(id=1, sentiment=mixed, warnings=[], statistics=None, confidence_scores=SentimentConfidenceScores(positive=0.48, neutral=0.06, negative=0.46), sentences=[SentenceSentiment(text=@user @user thanks for #lyft credit i can&#39;t use cause they don&#39;t offer wheelchair vans in pdx., sentiment=positive, confidence_scores=SentimentConfidenceScores(positive=0.95, neutral=0.02, negative=0.03), length=94, offset=0, mined_opinions=[]), SentenceSentiment(text=#disapointed #getthanked, sentiment=negative, confidence_scores=SentimentConfidenceScores(positive=0.02, neutral=0.1, negative=0.88), length=24, offset=98, mined_opinions=[])], is_error=False), AnalyzeSentimentResult(id=2, sentiment=positive, warnings=[], statistics=None, confidence_scores=SentimentConfidenceScores(positive=1.0, neutral=0.0, negative=0.0), sentences=[SentenceSentiment(text=#model   i love u take with u all the time in urð±!!!, sentiment=positive, confidence_scores=SentimentConfidenceScores(positive=1.0, neutral=0.0, negative=0.0), length=55, offset=0, mined_opinions=[]), SentenceSentiment(text=ððððð¦ð¦ð¦, sentiment=neutral, confidence_scores=SentimentConfidenceScores(positive=0.0, neutral=1.0, negative=0.0), length=28, offset=56, mined_opinions=[])], is_error=False), AnalyzeSentimentResult(id=3, sentiment=positive, warnings=[], statistics=None, confidence_scores=SentimentConfidenceScores(positive=0.59, neutral=0.37, negative=0.04), sentences=[SentenceSentiment(text= factsguide: society now    #motivation, sentiment=positive, confidence_scores=SentimentConfidenceScores(positive=0.59, neutral=0.37, negative=0.04), length=39, offset=0, mined_opinions=[])], is_error=False), AnalyzeSentimentResult(id=4, sentiment=negative, warnings=[], statistics=None, confidence_scores=SentimentConfidenceScores(positive=0.01, neutral=0.01, negative=0.98), sentences=[SentenceSentiment(text=[2/2] huge fan fare and big talking before they leave., sentiment=neutral, confidence_scores=SentimentConfidenceScores(positive=0.04, neutral=0.93, negative=0.03), length=54, offset=0, mined_opinions=[]), SentenceSentiment(text=chaos and pay disputes when they get there., sentiment=negative, confidence_scores=SentimentConfidenceScores(positive=0.01, neutral=0.01, negative=0.98), length=43, offset=55, mined_opinions=[]), SentenceSentiment(text=#allshowandnogo, sentiment=neutral, confidence_scores=SentimentConfidenceScores(positive=0.01, neutral=0.98, negative=0.01), length=15, offset=99, mined_opinions=[])], is_error=False), AnalyzeSentimentResult(id=5, sentiment=neutral, warnings=[], statistics=None, confidence_scores=SentimentConfidenceScores(positive=0.19, neutral=0.79, negative=0.02), sentences=[SentenceSentiment(text= @user camping tomorrow @user @user @user @user @user @user @user dannyâ¦, sentiment=neutral, confidence_scores=SentimentConfidenceScores(positive=0.19, neutral=0.79, negative=0.02), length=74, offset=0, mined_opinions=[])], is_error=False), AnalyzeSentimentResult(id=6, sentiment=negative, warnings=[], statistics=None, confidence_scores=SentimentConfidenceScores(positive=0.0, neutral=0.0, negative=1.0), sentences=[SentenceSentiment(text=the next school year is the year for exams.ð¯ can&#39;t think about that ð­ #school #exams   #hate #imagine #actorslife #revolutionschool #girl, sentiment=ne ...
# [AnalyzeSentimentResult(id=0, sentiment=negative, warnings=[], statistics=None, confidence_scores=SentimentConfidenceScores(positive=0.0, neutral=0.0, negative=1.0), sentences=[SentenceSentiment(text= @user when a father is dysfunctional and is so selfish he drags his kids into his dysfunction., sentiment=negative, confidence_scores=SentimentConfidenceScores(positive=0.0, neutral=0.0, negative=1.0), length=95, offset=0, mined_opinions=[]), SentenceSentiment(text=#run, sentiment=neutral, confidence_scores=SentimentConfidenceScores(positive=0.02, neutral=0.94, negative=0.04), length=4, offset=98, mined_opinions=[])], is_error=False), AnalyzeSentimentResult(id=1, sentiment=mixed, warnings=[], statistics=None, confidence_scores=SentimentConfidenceScores(positive=0.48, neutral=0.06, negative=0.46), sentences=[SentenceSentiment(text=@user @user thanks for #lyft credit i can&#39;t use cause they don&#39;t offer wheelchair vans in pdx., sentiment=positive, confidence_scores=SentimentConfidenceScores(positive=0.95, neutral=0.02, negative=0.03), length=94, offset=0, mined_opinions=[]), SentenceSentiment(text=#disapointed #getthanked, sentiment=negative, confidence_scores=SentimentConfidenceScores(positive=0.02, neutral=0.1, negative=0.88), length=24, offset=98, mined_opinions=[])], is_error=False), AnalyzeSentimentResult(id=2, sentiment=positive, warnings=[], statistics=None, confidence_scores=SentimentConfidenceScores(positive=1.0, neutral=0.0, negative=0.0), sentences=[SentenceSentiment(text=#model   i love u take with u all the time in urð±!!!, sentiment=positive, confidence_scores=SentimentConfidenceScores(positive=1.0, neutral=0.0,
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
df1.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[7]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>label</th>
#       <th>tweet</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>0</td>
#       <td>@user when a father is dysfunctional and is s...</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>0</td>
#       <td>@user @user thanks for #lyft credit i can't us...</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>0</td>
#       <td>bihday your majesty</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>0</td>
#       <td>#model   i love u take with u all the time in ...</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>0</td>
#       <td>factsguide: society now    #motivation</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
def sentiment_analysis_with_opinion_mining_example(client):

    documents = [
        "The food and service were unacceptable, but the concierge were nice"
    ]

    result = client.analyze_sentiment(documents, show_opinion_mining=True)
    doc_result = [doc for doc in result if not doc.is_error]

    positive_reviews = [doc for doc in doc_result if doc.sentiment == "positive"]
    negative_reviews = [doc for doc in doc_result if doc.sentiment == "negative"]

    positive_mined_opinions = []
    mixed_mined_opinions = []
    negative_mined_opinions = []

    for document in doc_result:
        print("Document Sentiment: {}".format(document.sentiment))
        print("Overall scores: positive={0:.2f}; neutral={1:.2f}; negative={2:.2f} \n".format(
            document.confidence_scores.positive,
            document.confidence_scores.neutral,
            document.confidence_scores.negative,
        ))
        for sentence in document.sentences:
            print("Sentence: {}".format(sentence.text))
            print("Sentence sentiment: {}".format(sentence.sentiment))
            print("Sentence score:\nPositive={0:.2f}\nNeutral={1:.2f}\nNegative={2:.2f}\n".format(
                sentence.confidence_scores.positive,
                sentence.confidence_scores.neutral,
                sentence.confidence_scores.negative,
            ))
            for mined_opinion in sentence.mined_opinions:
                aspect = mined_opinion.aspect
                print("......'{}' aspect '{}'".format(aspect.sentiment, aspect.text))
                print("......Aspect score:\n......Positive={0:.2f}\n......Negative={1:.2f}\n".format(
                    aspect.confidence_scores.positive,
                    aspect.confidence_scores.negative,
                ))
                for opinion in mined_opinion.opinions:
                    print("......'{}' opinion '{}'".format(opinion.sentiment, opinion.text))
                    print("......Opinion score:\n......Positive={0:.2f}\n......Negative={1:.2f}\n".format(
                        opinion.confidence_scores.positive,
                        opinion.confidence_scores.negative,
                    ))
            print("\n")
        print("\n")
          
sentiment_analysis_with_opinion_mining_example(client)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Document Sentiment: positive
# Overall scores: positive=0.84; neutral=0.00; negative=0.16
#
# Sentence: The food and service were unacceptable, but the concierge were nice
# Sentence sentiment: positive
# Sentence score:
# Positive=0.84
# Neutral=0.00
# Negative=0.16
#
# ......&#39;negative&#39; aspect &#39;food&#39;
# ......Aspect score:
# ......Positive=0.01
# ......Negative=0.99
#
# ......&#39;negative&#39; opinion &#39;unacceptable&#39;
# ......Opinion score:
# ......Positive=0.01
# ......Negative=0.99
#
# ......&#39;negative&#39; aspect &#39;service&#39;
# ......Aspect score:
# ......Positive=0.01
# ......Negative=0.99
#
# ......&#39;negative&#39; opinion &#39;unacceptable&#39;
# ......Opinion score:
# ......Positive=0.01
# ......Negative=0.99
#
# ......&#39;positive&#39; aspect &#39;concierge&#39;
# ......Aspect score:
# ......Positive=1.00
# ......Negative=0.00
#
# ......&#39;positive&#39; opinion &#39;nice&#39;
# ......Opinion score:
# ......Positive=1.00
# ......Negative=0.00
#
#
#
#
#
# </div>

# %%
def language_detection_example(client):
    try:
        documents = ["Ce document est rédigé en Français."]
        response = client.detect_language(documents = documents, country_hint = 'us')[0]
        print("Language: ", response.primary_language.name)

    except Exception as err:
        print("Encountered exception. {}".format(err))
language_detection_example(client)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Language:  French
# </div>

# %%
def entity_recognition_example(client):

    try:
        documents = ["I had a wonderful trip to Seattle last week."]
        result = client.recognize_entities(documents = documents)[0]

        print("Named Entities:\n")
        for entity in result.entities:
            print("\tText: \t", entity.text, "\tCategory: \t", entity.category, "\tSubCategory: \t", entity.subcategory,
                    "\n\tConfidence Score: \t", round(entity.confidence_score, 2), "\tLength: \t", entity.length, "\tOffset: \t", entity.offset, "\n")

    except Exception as err:
        print("Encountered exception. {}".format(err))
entity_recognition_example(client)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Named Entities:
#
# Encountered exception. &#39;CategorizedEntity&#39; object has no attribute &#39;length&#39;
# </div>

# %%
def entity_linking_example(client):

    try:
        documents = ["""Microsoft was founded by Bill Gates and Paul Allen on April 4, 1975, 
        to develop and sell BASIC interpreters for the Altair 8800. 
        During his career at Microsoft, Gates held the positions of chairman,
        chief executive officer, president and chief software architect, 
        while also being the largest individual shareholder until May 2014."""]
        result = client.recognize_linked_entities(documents = documents)[0]

        print("Linked Entities:\n")
        for entity in result.entities:
            print("\tName: ", entity.name, "\tId: ", entity.data_source_entity_id, "\tUrl: ", entity.url,
            "\n\tData Source: ", entity.data_source)
            print("\tMatches:")
            for match in entity.matches:
                print("\t\tText:", match.text)
                print("\t\tConfidence Score: {0:.2f}".format(match.confidence_score))
                print("\t\tOffset: {}".format(match.offset))
                print("\t\tLength: {}".format(match.length))
            
    except Exception as err:
        print("Encountered exception. {}".format(err))
entity_linking_example(client)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Linked Entities:
#
# 	Name:  Microsoft 	Id:  Microsoft 	Url:  https://en.wikipedia.org/wiki/Microsoft
# 	Data Source:  Wikipedia
# 	Matches:
# 		Text: Microsoft
# 		Confidence Score: 0.55
# 		Offset: 0
# Encountered exception. &#39;LinkedEntityMatch&#39; object has no attribute &#39;length&#39;
# </div>
